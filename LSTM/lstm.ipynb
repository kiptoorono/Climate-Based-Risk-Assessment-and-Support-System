# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import os
import math

# Create output directories
os.makedirs("forecasts", exist_ok=True)
os.makedirs("plots", exist_ok=True)
os.makedirs("evaluations", exist_ok=True)

# Load and prepare data
df = pd.read_csv("E:\Agriculture project\Data\Processed\Merged_data_features.csv", parse_dates=["Date"])
df.columns = df.columns.str.strip()
df.set_index("Date", inplace=True)
df.index = pd.to_datetime(df.index, errors="coerce")
df = df[df.index.notna()]

# Parameters
forecast_horizon = 60
sequence_length = 24

# Identify unique regions
regions = {col.split('_')[0] for col in df.columns if col.endswith(("_rain", "_soil", "_temp"))}

for region in regions:
    rain_col, soil_col, temp_col = f"{region}_rain", f"{region}_soil", f"{region}_temp"
    if rain_col not in df or soil_col not in df or temp_col not in df:
        print(f"Skipping {region}: Missing data")
        continue

    region_data = df[[rain_col, soil_col, temp_col]].dropna()
    if len(region_data) < sequence_length + forecast_horizon:
        print(f"Skipping {region}: Not enough data")
        continue

    # Scale data
    feature_scaler = MinMaxScaler()
    target_scaler = MinMaxScaler()
    scaled_features = feature_scaler.fit_transform(region_data)
    scaled_targets = target_scaler.fit_transform(region_data)

    # Create sequences
    X, y = [], []
    for i in range(len(scaled_features) - sequence_length):
        X.append(scaled_features[i:i+sequence_length])
        y.append(scaled_targets[i+sequence_length])

    X, y = np.array(X), np.array(y)
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Build LSTM model
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=(sequence_length, X.shape[2])),
        Dropout(0.3),
        LSTM(624),
        Dropout(0.3),
        Dense(3)  # Changed from 2 to 3 to include temperature
    ])

    model.compile(optimizer='adam', loss='mse')
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

    # Train model
    history = model.fit(
        X_train, y_train, 
        epochs=150, 
        batch_size=32, 
        validation_data=(X_test, y_test), 
        callbacks=[early_stopping],
        verbose=1
    )

    # Evaluate model on test data
    y_pred_scaled = model.predict(X_test)
    y_pred = target_scaler.inverse_transform(y_pred_scaled)
    y_test_actual = target_scaler.inverse_transform(y_test)
    
    # Calculate metrics for each variable
    rain_rmse = math.sqrt(mean_squared_error(y_test_actual[:, 0], y_pred[:, 0]))
    rain_mae = mean_absolute_error(y_test_actual[:, 0], y_pred[:, 0])
    rain_r2 = r2_score(y_test_actual[:, 0], y_pred[:, 0])
    
    soil_rmse = math.sqrt(mean_squared_error(y_test_actual[:, 1], y_pred[:, 1]))
    soil_mae = mean_absolute_error(y_test_actual[:, 1], y_pred[:, 1])
    soil_r2 = r2_score(y_test_actual[:, 1], y_pred[:, 1])
    
    temp_rmse = math.sqrt(mean_squared_error(y_test_actual[:, 2], y_pred[:, 2]))
    temp_mae = mean_absolute_error(y_test_actual[:, 2], y_pred[:, 2])
    temp_r2 = r2_score(y_test_actual[:, 2], y_pred[:, 2])
    
    # Store evaluation metrics in a DataFrame and save to CSV
    eval_metrics = {
        'Metric': ['RMSE', 'MAE', 'R²'],
        'Rainfall': [rain_rmse, rain_mae, rain_r2],
        'Soil_Moisture': [soil_rmse, soil_mae, soil_r2],
        'Temperature': [temp_rmse, temp_mae, temp_r2]
    }
    
    eval_df = pd.DataFrame(eval_metrics)
    eval_df.to_csv(f"evaluations/{region}_evaluation.csv", index=False)
    
    # Generate forecasts
    last_sequence = X[-1].reshape(1, sequence_length, X.shape[2])
    future_predictions = []
    for _ in range(forecast_horizon):
        pred = model.predict(last_sequence)[0]
        future_predictions.append(pred)
        last_sequence = np.vstack([last_sequence[0][1:], pred]).reshape(1, sequence_length, X.shape[2])

    # Convert predictions back to original scale
    future_predictions = target_scaler.inverse_transform(future_predictions)
    future_dates = pd.date_range(region_data.index[-1] + pd.DateOffset(months=1), periods=forecast_horizon, freq="M")
    
    # Create forecast DataFrame that includes evaluation metrics
    forecast_df = pd.DataFrame({
        "Date": future_dates, 
        f"{rain_col}_forecast": future_predictions[:, 0], 
        f"{soil_col}_forecast": future_predictions[:, 1],
        f"{temp_col}_forecast": future_predictions[:, 2]  # Add temperature forecast
    })
    
    # Add evaluation metrics as metadata at the top of the file
    with open(f"forecasts/{region}_forecast.csv", "w") as f:
        f.write(f"# Evaluation Metrics for {region}\n")
        f.write(f"# Rainfall RMSE: {rain_rmse:.4f}, MAE: {rain_mae:.4f}, R²: {rain_r2:.4f}\n")
        f.write(f"# Soil Moisture RMSE: {soil_rmse:.4f}, MAE: {soil_mae:.4f}, R²: {soil_r2:.4f}\n")
        f.write(f"# Temperature RMSE: {temp_rmse:.4f}, MAE: {temp_mae:.4f}, R²: {temp_r2:.4f}\n")
    
    # Append the forecast data
    forecast_df.to_csv(f"forecasts/{region}_forecast.csv", index=False, mode='a')

    # Plot results with evaluation metrics in the title
    # Rainfall plot
    plt.figure(figsize=(14, 6))
    plt.plot(region_data.index[-100:], region_data[rain_col].values[-100:], label='Historical Rainfall', color='blue')
    plt.plot(future_dates, future_predictions[:, 0], label='Forecast Rainfall', color='red', linestyle='--')
    plt.legend()
    plt.title(f'Rainfall Forecast for {region}\nRMSE: {rain_rmse:.4f}, R²: {rain_r2:.4f}')
    plt.savefig(f"plots/{region}_rainfall_forecast.png")
    plt.close()

    # Soil moisture plot
    plt.figure(figsize=(14, 6))
    plt.plot(region_data.index[-100:], region_data[soil_col].values[-100:], label='Historical Soil Moisture', color='green')
    plt.plot(future_dates, future_predictions[:, 1], label='Forecast Soil Moisture', color='orange', linestyle='--')
    plt.legend()
    plt.title(f'Soil Moisture Forecast for {region}\nRMSE: {soil_rmse:.4f}, R²: {soil_r2:.4f}')
    plt.savefig(f"plots/{region}_soil_forecast.png")
    plt.close()
    
    # Temperature plot - Added for temperature
    plt.figure(figsize=(14, 6))
    plt.plot(region_data.index[-100:], region_data[temp_col].values[-100:], label='Historical Temperature', color='purple')
    plt.plot(future_dates, future_predictions[:, 2], label='Forecast Temperature', color='brown', linestyle='--')
    plt.legend()
    plt.title(f'Temperature Forecast for {region}\nRMSE: {temp_rmse:.4f}, R²: {temp_r2:.4f}')
    plt.savefig(f"plots/{region}_temperature_forecast.png")
    plt.close()

    # Create and save actual vs. predicted plots for the test set
    test_dates = region_data.index[train_size+sequence_length:train_size+sequence_length+len(y_test)]
    
    # Rainfall test validation
    plt.figure(figsize=(14, 6))
    plt.plot(test_dates, y_test_actual[:, 0], label='Actual Rainfall', color='blue')
    plt.plot(test_dates, y_pred[:, 0], label='Predicted Rainfall', color='red', linestyle='--')
    plt.legend()
    plt.title(f'Rainfall Test Set Predictions for {region}\nRMSE: {rain_rmse:.4f}, R²: {rain_r2:.4f}')
    plt.savefig(f"plots/{region}_rainfall_test_validation.png")
    plt.close()
    
    # Soil moisture test validation
    plt.figure(figsize=(14, 6))
    plt.plot(test_dates, y_test_actual[:, 1], label='Actual Soil Moisture', color='green')
    plt.plot(test_dates, y_pred[:, 1], label='Predicted Soil Moisture', color='orange', linestyle='--')
    plt.legend()
    plt.title(f'Soil Moisture Test Set Predictions for {region}\nRMSE: {soil_rmse:.4f}, R²: {soil_r2:.4f}')
    plt.savefig(f"plots/{region}_soil_test_validation.png")
    plt.close()
    
    # Temperature test validation - Added for temperature
    plt.figure(figsize=(14, 6))
    plt.plot(test_dates, y_test_actual[:, 2], label='Actual Temperature', color='purple')
    plt.plot(test_dates, y_pred[:, 2], label='Predicted Temperature', color='brown', linestyle='--')
    plt.legend()
    plt.title(f'Temperature Test Set Predictions for {region}\nRMSE: {temp_rmse:.4f}, R²: {temp_r2:.4f}')
    plt.savefig(f"plots/{region}_temperature_test_validation.png")
    plt.close()

print("Forecasting and evaluation completed.")
# Out:
# Epoch 1/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 552ms/step - loss: 0.0788 - val_loss: 0.0514
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 385ms/step - loss: 0.0440 - val_loss: 0.0491
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 0.0419 - val_loss: 0.0528
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 538ms/step - loss: 0.0450 - val_loss: 0.0458
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - loss: 0.0371 - val_loss: 0.0444
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - loss: 0.0316 - val_loss: 0.0306
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 0.0221 - val_loss: 0.0317
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 0.0226 - val_loss: 0.0273
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - loss: 0.0228 - val_loss: 0.0271
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 413ms/step - loss: 0.0214 - val_loss: 0.0266
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 457ms/step - loss: 0.0200 - val_loss: 0.0242
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 0.0199 - val_loss: 0.0255
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 452ms/step - loss: 0.0190 - val_loss: 0.0255
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 409ms/step - loss: 0.0187 - val_loss: 0.0235
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - loss: 0.0194 - val_loss: 0.0242
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 518ms/step - loss: 0.0176 - val_loss: 0.0254
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 506ms/step - loss: 0.0170 - val_loss: 0.0206
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 516ms/step - loss: 0.0171 - val_loss: 0.0196
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 462ms/step - loss: 0.0158 - val_loss: 0.0208
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - loss: 0.0149 - val_loss: 0.0215
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 406ms/step - loss: 0.0141 - val_loss: 0.0177
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 404ms/step - loss: 0.0116 - val_loss: 0.0181
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 399ms/step - loss: 0.0124 - val_loss: 0.0155
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0120 - val_loss: 0.0161
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0099 - val_loss: 0.0153
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0103 - val_loss: 0.0154
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 0.0096 - val_loss: 0.0169
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 449ms/step - loss: 0.0126 - val_loss: 0.0164
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - loss: 0.0126 - val_loss: 0.0151
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - loss: 0.0101 - val_loss: 0.0134
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 395ms/step - loss: 0.0104 - val_loss: 0.0149
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 414ms/step - loss: 0.0088 - val_loss: 0.0129
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 491ms/step - loss: 0.0098 - val_loss: 0.0146
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 409ms/step - loss: 0.0094 - val_loss: 0.0127
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0087 - val_loss: 0.0133
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 0.0081 - val_loss: 0.0132
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 0.0093 - val_loss: 0.0142
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - loss: 0.0086 - val_loss: 0.0134
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - loss: 0.0085 - val_loss: 0.0127
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0083 - val_loss: 0.0130
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - loss: 0.0076 - val_loss: 0.0127
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0088 - val_loss: 0.0139
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - loss: 0.0076 - val_loss: 0.0128
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 0.0079 - val_loss: 0.0136
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0074 - val_loss: 0.0121
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - loss: 0.0083 - val_loss: 0.0135
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - loss: 0.0074 - val_loss: 0.0128
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - loss: 0.0083 - val_loss: 0.0133
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 0.0078 - val_loss: 0.0135
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 0.0079 - val_loss: 0.0128
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - loss: 0.0072 - val_loss: 0.0126
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - loss: 0.0074 - val_loss: 0.0129
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 0.0067 - val_loss: 0.0115
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 0.0063 - val_loss: 0.0123
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 407ms/step - loss: 0.0075 - val_loss: 0.0125
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 473ms/step - loss: 0.0064 - val_loss: 0.0131
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 402ms/step - loss: 0.0062 - val_loss: 0.0128
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0070 - val_loss: 0.0129
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - loss: 0.0069 - val_loss: 0.0116
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 392ms/step - loss: 0.0063 - val_loss: 0.0119
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0058 - val_loss: 0.0123
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - loss: 0.0065 - val_loss: 0.0118
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 403ms/step - loss: 0.0062 - val_loss: 0.0122
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - loss: 0.0073 - val_loss: 0.0121
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0070 - val_loss: 0.0114
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 452ms/step - loss: 0.0068 - val_loss: 0.0113
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 0.0052 - val_loss: 0.0118
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - loss: 0.0055 - val_loss: 0.0123
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0062 - val_loss: 0.0118
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 402ms/step - loss: 0.0068 - val_loss: 0.0131
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 0.0068 - val_loss: 0.0112
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 459ms/step - loss: 0.0066 - val_loss: 0.0119
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 443ms/step - loss: 0.0058 - val_loss: 0.0118
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 664ms/step - loss: 0.0068 - val_loss: 0.0125
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - loss: 0.0056 - val_loss: 0.0118
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 305ms/step - loss: 0.0063 - val_loss: 0.0118
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0057 - val_loss: 0.0132
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 297ms/step - loss: 0.0066 - val_loss: 0.0119
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0060 - val_loss: 0.0129
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - loss: 0.0062 - val_loss: 0.0128
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0062 - val_loss: 0.0122
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0057 - val_loss: 0.0117
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - loss: 0.0053 - val_loss: 0.0128
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0052 - val_loss: 0.0121
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - loss: 0.0058 - val_loss: 0.0133
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 293ms/step - loss: 0.0060 - val_loss: 0.0122
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# Epoch 1/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 611ms/step - loss: 0.0686 - val_loss: 0.0429
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.0317 - val_loss: 0.0396
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 329ms/step - loss: 0.0287 - val_loss: 0.0387
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - loss: 0.0292 - val_loss: 0.0374
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - loss: 0.0292 - val_loss: 0.0404
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - loss: 0.0294 - val_loss: 0.0373
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - loss: 0.0290 - val_loss: 0.0342
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 0.0243 - val_loss: 0.0337
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - loss: 0.0262 - val_loss: 0.0370
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - loss: 0.0279 - val_loss: 0.0328
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 372ms/step - loss: 0.0226 - val_loss: 0.0305
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 446ms/step - loss: 0.0218 - val_loss: 0.0267
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 461ms/step - loss: 0.0200 - val_loss: 0.0239
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 325ms/step - loss: 0.0176 - val_loss: 0.0244
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 399ms/step - loss: 0.0157 - val_loss: 0.0223
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - loss: 0.0173 - val_loss: 0.0229
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 316ms/step - loss: 0.0164 - val_loss: 0.0220
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - loss: 0.0146 - val_loss: 0.0216
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 304ms/step - loss: 0.0171 - val_loss: 0.0195
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - loss: 0.0143 - val_loss: 0.0200
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - loss: 0.0151 - val_loss: 0.0162
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0107 - val_loss: 0.0156
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0110 - val_loss: 0.0159
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - loss: 0.0113 - val_loss: 0.0151
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 299ms/step - loss: 0.0106 - val_loss: 0.0146
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step - loss: 0.0098 - val_loss: 0.0156
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - loss: 0.0112 - val_loss: 0.0151
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0098 - val_loss: 0.0144
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.0101 - val_loss: 0.0134
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 308ms/step - loss: 0.0099 - val_loss: 0.0136
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.0102 - val_loss: 0.0140
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 300ms/step - loss: 0.0091 - val_loss: 0.0123
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.0082 - val_loss: 0.0131
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - loss: 0.0080 - val_loss: 0.0128
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - loss: 0.0078 - val_loss: 0.0121
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - loss: 0.0081 - val_loss: 0.0124
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - loss: 0.0081 - val_loss: 0.0121
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0075 - val_loss: 0.0119
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 383ms/step - loss: 0.0078 - val_loss: 0.0114
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - loss: 0.0079 - val_loss: 0.0127
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.0081 - val_loss: 0.0121
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - loss: 0.0079 - val_loss: 0.0115
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - loss: 0.0059 - val_loss: 0.0115
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - loss: 0.0082 - val_loss: 0.0122
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0083 - val_loss: 0.0115
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.0070 - val_loss: 0.0110
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0080 - val_loss: 0.0121
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0070 - val_loss: 0.0110
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 298ms/step - loss: 0.0080 - val_loss: 0.0126
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - loss: 0.0076 - val_loss: 0.0121
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0075 - val_loss: 0.0112
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0090 - val_loss: 0.0123
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - loss: 0.0070 - val_loss: 0.0114
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - loss: 0.0074 - val_loss: 0.0119
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 300ms/step - loss: 0.0068 - val_loss: 0.0107
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 268ms/step - loss: 0.0061 - val_loss: 0.0116
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - loss: 0.0061 - val_loss: 0.0115
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.0067 - val_loss: 0.0115
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - loss: 0.0080 - val_loss: 0.0110
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 256ms/step - loss: 0.0084 - val_loss: 0.0117
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0076 - val_loss: 0.0109
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - loss: 0.0067 - val_loss: 0.0117
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 260ms/step - loss: 0.0062 - val_loss: 0.0111
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - loss: 0.0070 - val_loss: 0.0106
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.0069 - val_loss: 0.0116
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0065 - val_loss: 0.0107
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 0.0064 - val_loss: 0.0108
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - loss: 0.0059 - val_loss: 0.0111
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 0.0064 - val_loss: 0.0109
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - loss: 0.0058 - val_loss: 0.0116
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - loss: 0.0071 - val_loss: 0.0106
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - loss: 0.0060 - val_loss: 0.0107
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - loss: 0.0068 - val_loss: 0.0112
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - loss: 0.0065 - val_loss: 0.0110
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - loss: 0.0063 - val_loss: 0.0110
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0060 - val_loss: 0.0112
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0057 - val_loss: 0.0106
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - loss: 0.0057 - val_loss: 0.0105
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - loss: 0.0069 - val_loss: 0.0105
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - loss: 0.0068 - val_loss: 0.0116
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - loss: 0.0057 - val_loss: 0.0110
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - loss: 0.0052 - val_loss: 0.0105
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 311ms/step - loss: 0.0055 - val_loss: 0.0109
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 362ms/step - loss: 0.0061 - val_loss: 0.0107
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - loss: 0.0065 - val_loss: 0.0118
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - loss: 0.0070 - val_loss: 0.0118
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - loss: 0.0064 - val_loss: 0.0100
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 0.0065 - val_loss: 0.0107
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 440ms/step - loss: 0.0068 - val_loss: 0.0106
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - loss: 0.0067 - val_loss: 0.0104
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - loss: 0.0059 - val_loss: 0.0114
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.0059 - val_loss: 0.0113
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - loss: 0.0062 - val_loss: 0.0107
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - loss: 0.0065 - val_loss: 0.0118
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - loss: 0.0062 - val_loss: 0.0107
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 370ms/step - loss: 0.0057 - val_loss: 0.0111
# Epoch 97/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 353ms/step - loss: 0.0056 - val_loss: 0.0102
# Epoch 98/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 330ms/step - loss: 0.0048 - val_loss: 0.0108
# Epoch 99/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 312ms/step - loss: 0.0071 - val_loss: 0.0113
# Epoch 100/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0070 - val_loss: 0.0106
# Epoch 101/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - loss: 0.0056 - val_loss: 0.0115
# Epoch 102/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0074 - val_loss: 0.0102
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Epoch 1/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 336ms/step - loss: 0.0810 - val_loss: 0.0508
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - loss: 0.0425 - val_loss: 0.0470
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - loss: 0.0379 - val_loss: 0.0448
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - loss: 0.0378 - val_loss: 0.0424
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0347 - val_loss: 0.0398
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - loss: 0.0302 - val_loss: 0.0349
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0265 - val_loss: 0.0312
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - loss: 0.0234 - val_loss: 0.0286
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 577ms/step - loss: 0.0236 - val_loss: 0.0291
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - loss: 0.0222 - val_loss: 0.0262
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.0196 - val_loss: 0.0239
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - loss: 0.0187 - val_loss: 0.0241
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0185 - val_loss: 0.0218
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 357ms/step - loss: 0.0178 - val_loss: 0.0209
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 547ms/step - loss: 0.0169 - val_loss: 0.0229
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 565ms/step - loss: 0.0178 - val_loss: 0.0214
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 465ms/step - loss: 0.0169 - val_loss: 0.0221
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 404ms/step - loss: 0.0169 - val_loss: 0.0205
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 475ms/step - loss: 0.0152 - val_loss: 0.0186
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - loss: 0.0152 - val_loss: 0.0168
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 0.0125 - val_loss: 0.0180
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - loss: 0.0138 - val_loss: 0.0174
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 379ms/step - loss: 0.0153 - val_loss: 0.0169
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 367ms/step - loss: 0.0132 - val_loss: 0.0172
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 591ms/step - loss: 0.0130 - val_loss: 0.0154
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 441ms/step - loss: 0.0115 - val_loss: 0.0168
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 0.0130 - val_loss: 0.0191
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 560ms/step - loss: 0.0117 - val_loss: 0.0159
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 581ms/step - loss: 0.0130 - val_loss: 0.0169
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 517ms/step - loss: 0.0137 - val_loss: 0.0156
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 628ms/step - loss: 0.0121 - val_loss: 0.0147
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - loss: 0.0115 - val_loss: 0.0147
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 621ms/step - loss: 0.0139 - val_loss: 0.0146
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 512ms/step - loss: 0.0135 - val_loss: 0.0157
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 512ms/step - loss: 0.0130 - val_loss: 0.0153
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 460ms/step - loss: 0.0126 - val_loss: 0.0155
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 418ms/step - loss: 0.0108 - val_loss: 0.0151
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0107 - val_loss: 0.0152
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - loss: 0.0113 - val_loss: 0.0145
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0119 - val_loss: 0.0153
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - loss: 0.0126 - val_loss: 0.0157
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 565ms/step - loss: 0.0110 - val_loss: 0.0149
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - loss: 0.0102 - val_loss: 0.0144
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - loss: 0.0114 - val_loss: 0.0147
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 463ms/step - loss: 0.0106 - val_loss: 0.0144
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - loss: 0.0108 - val_loss: 0.0147
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - loss: 0.0113 - val_loss: 0.0142
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - loss: 0.0122 - val_loss: 0.0139
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 519ms/step - loss: 0.0100 - val_loss: 0.0145
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 0.0106 - val_loss: 0.0144
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 406ms/step - loss: 0.0113 - val_loss: 0.0149
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 0.0101 - val_loss: 0.0151
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 0.0116 - val_loss: 0.0141
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - loss: 0.0096 - val_loss: 0.0147
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - loss: 0.0104 - val_loss: 0.0148
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 0.0114 - val_loss: 0.0143
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 407ms/step - loss: 0.0113 - val_loss: 0.0153
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 413ms/step - loss: 0.0107 - val_loss: 0.0150
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - loss: 0.0117 - val_loss: 0.0146
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 0.0096 - val_loss: 0.0140
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - loss: 0.0095 - val_loss: 0.0147
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0098 - val_loss: 0.0139
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 488ms/step - loss: 0.0090 - val_loss: 0.0138
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 441ms/step - loss: 0.0100 - val_loss: 0.0138
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 454ms/step - loss: 0.0100 - val_loss: 0.0140
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 524ms/step - loss: 0.0106 - val_loss: 0.0146
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 0.0109 - val_loss: 0.0137
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 0.0100 - val_loss: 0.0144
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - loss: 0.0089 - val_loss: 0.0147
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 523ms/step - loss: 0.0113 - val_loss: 0.0149
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - loss: 0.0103 - val_loss: 0.0140
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step - loss: 0.0099 - val_loss: 0.0144
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 514ms/step - loss: 0.0082 - val_loss: 0.0138
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 0.0103 - val_loss: 0.0142
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 0.0095 - val_loss: 0.0136
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 0.0094 - val_loss: 0.0142
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0083 - val_loss: 0.0138
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - loss: 0.0098 - val_loss: 0.0151
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 541ms/step - loss: 0.0095 - val_loss: 0.0136
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - loss: 0.0088 - val_loss: 0.0143
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - loss: 0.0094 - val_loss: 0.0140
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 507ms/step - loss: 0.0095 - val_loss: 0.0148
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 394ms/step - loss: 0.0097 - val_loss: 0.0134
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - loss: 0.0097 - val_loss: 0.0150
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - loss: 0.0093 - val_loss: 0.0141
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - loss: 0.0097 - val_loss: 0.0142
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 0.0095 - val_loss: 0.0144
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - loss: 0.0098 - val_loss: 0.0148
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 0.0092 - val_loss: 0.0145
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - loss: 0.0089 - val_loss: 0.0143
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - loss: 0.0091 - val_loss: 0.0141
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 402ms/step - loss: 0.0072 - val_loss: 0.0147
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 384ms/step - loss: 0.0097 - val_loss: 0.0136
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - loss: 0.0096 - val_loss: 0.0141
# Epoch 97/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 382ms/step - loss: 0.0089 - val_loss: 0.0140
# Epoch 98/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 384ms/step - loss: 0.0097 - val_loss: 0.0142
# Epoch 99/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 395ms/step - loss: 0.0086 - val_loss: 0.0144
# Epoch 100/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 379ms/step - loss: 0.0090 - val_loss: 0.0136
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 446ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Epoch 1/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 503ms/step - loss: 0.0693 - val_loss: 0.0530
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 399ms/step - loss: 0.0366 - val_loss: 0.0463
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 407ms/step - loss: 0.0365 - val_loss: 0.0465
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 0.0356 - val_loss: 0.0495
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 406ms/step - loss: 0.0363 - val_loss: 0.0457
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 460ms/step - loss: 0.0306 - val_loss: 0.0410
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - loss: 0.0302 - val_loss: 0.0391
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 328ms/step - loss: 0.0260 - val_loss: 0.0324
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - loss: 0.0229 - val_loss: 0.0353
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0220 - val_loss: 0.0274
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0193 - val_loss: 0.0252
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 541ms/step - loss: 0.0225 - val_loss: 0.0270
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0188 - val_loss: 0.0274
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 0.0189 - val_loss: 0.0223
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 418ms/step - loss: 0.0162 - val_loss: 0.0227
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - loss: 0.0166 - val_loss: 0.0229
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 0.0158 - val_loss: 0.0189
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 0.0148 - val_loss: 0.0180
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 0.0133 - val_loss: 0.0180
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 505ms/step - loss: 0.0129 - val_loss: 0.0181
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 421ms/step - loss: 0.0129 - val_loss: 0.0172
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 0.0116 - val_loss: 0.0168
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 0.0123 - val_loss: 0.0143
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 0.0098 - val_loss: 0.0140
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - loss: 0.0098 - val_loss: 0.0148
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0103 - val_loss: 0.0171
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 0.0102 - val_loss: 0.0140
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 409ms/step - loss: 0.0094 - val_loss: 0.0145
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 0.0089 - val_loss: 0.0145
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0090 - val_loss: 0.0154
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - loss: 0.0097 - val_loss: 0.0135
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0074 - val_loss: 0.0128
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 403ms/step - loss: 0.0076 - val_loss: 0.0142
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 0.0078 - val_loss: 0.0142
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 0.0083 - val_loss: 0.0139
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - loss: 0.0081 - val_loss: 0.0136
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 399ms/step - loss: 0.0084 - val_loss: 0.0128
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0084 - val_loss: 0.0141
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - loss: 0.0083 - val_loss: 0.0139
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step - loss: 0.0064 - val_loss: 0.0127
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - loss: 0.0073 - val_loss: 0.0132
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - loss: 0.0074 - val_loss: 0.0128
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 491ms/step - loss: 0.0078 - val_loss: 0.0125
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - loss: 0.0071 - val_loss: 0.0132
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 413ms/step - loss: 0.0077 - val_loss: 0.0134
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 392ms/step - loss: 0.0086 - val_loss: 0.0138
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - loss: 0.0073 - val_loss: 0.0131
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 392ms/step - loss: 0.0074 - val_loss: 0.0126
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 0.0066 - val_loss: 0.0135
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - loss: 0.0088 - val_loss: 0.0133
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 402ms/step - loss: 0.0080 - val_loss: 0.0134
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - loss: 0.0060 - val_loss: 0.0126
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 399ms/step - loss: 0.0066 - val_loss: 0.0134
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 0.0071 - val_loss: 0.0126
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 555ms/step - loss: 0.0064 - val_loss: 0.0133
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 626ms/step - loss: 0.0070 - val_loss: 0.0134
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 611ms/step - loss: 0.0063 - val_loss: 0.0162
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 424ms/step - loss: 0.0099 - val_loss: 0.0124
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 0.0063 - val_loss: 0.0125
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 0.0077 - val_loss: 0.0134
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 0.0063 - val_loss: 0.0121
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 0.0066 - val_loss: 0.0124
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 418ms/step - loss: 0.0064 - val_loss: 0.0129
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 460ms/step - loss: 0.0060 - val_loss: 0.0126
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 423ms/step - loss: 0.0064 - val_loss: 0.0131
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 399ms/step - loss: 0.0068 - val_loss: 0.0137
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 375ms/step - loss: 0.0064 - val_loss: 0.0132
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 361ms/step - loss: 0.0060 - val_loss: 0.0121
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - loss: 0.0067 - val_loss: 0.0137
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0067 - val_loss: 0.0128
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0064 - val_loss: 0.0120
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - loss: 0.0067 - val_loss: 0.0134
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - loss: 0.0073 - val_loss: 0.0123
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0055 - val_loss: 0.0128
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 268ms/step - loss: 0.0067 - val_loss: 0.0128
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0064 - val_loss: 0.0127
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0066 - val_loss: 0.0129
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - loss: 0.0064 - val_loss: 0.0123
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0061 - val_loss: 0.0121
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 297ms/step - loss: 0.0063 - val_loss: 0.0119
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - loss: 0.0062 - val_loss: 0.0124
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - loss: 0.0058 - val_loss: 0.0126
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0061 - val_loss: 0.0125
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 0.0062 - val_loss: 0.0125
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - loss: 0.0061 - val_loss: 0.0122
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - loss: 0.0063 - val_loss: 0.0123
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0058 - val_loss: 0.0121
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 268ms/step - loss: 0.0065 - val_loss: 0.0124
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0054 - val_loss: 0.0123
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - loss: 0.0056 - val_loss: 0.0118
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0059 - val_loss: 0.0124
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - loss: 0.0058 - val_loss: 0.0122
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.0062 - val_loss: 0.0123
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - loss: 0.0058 - val_loss: 0.0123
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0060 - val_loss: 0.0116
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - loss: 0.0055 - val_loss: 0.0125
# Epoch 97/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.0058 - val_loss: 0.0124
# Epoch 98/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - loss: 0.0058 - val_loss: 0.0121
# Epoch 99/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0055 - val_loss: 0.0127
# Epoch 100/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - loss: 0.0055 - val_loss: 0.0126
# Epoch 101/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0056 - val_loss: 0.0125
# Epoch 102/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - loss: 0.0058 - val_loss: 0.0124
# Epoch 103/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0060 - val_loss: 0.0123
# Epoch 104/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - loss: 0.0050 - val_loss: 0.0122
# Epoch 105/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0055 - val_loss: 0.0122
# Epoch 106/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - loss: 0.0060 - val_loss: 0.0125
# Epoch 107/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0060 - val_loss: 0.0126
# Epoch 108/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - loss: 0.0060 - val_loss: 0.0123
# Epoch 109/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - loss: 0.0057 - val_loss: 0.0119
# Epoch 110/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - loss: 0.0052 - val_loss: 0.0123
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Epoch 1/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 393ms/step - loss: 0.0695 - val_loss: 0.0455
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step - loss: 0.0378 - val_loss: 0.0419
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - loss: 0.0332 - val_loss: 0.0414
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 774ms/step - loss: 0.0314 - val_loss: 0.0407
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 792ms/step - loss: 0.0309 - val_loss: 0.0367
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 571ms/step - loss: 0.0288 - val_loss: 0.0334
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 795ms/step - loss: 0.0251 - val_loss: 0.0283
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 456ms/step - loss: 0.0227 - val_loss: 0.0276
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - loss: 0.0183 - val_loss: 0.0278
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - loss: 0.0189 - val_loss: 0.0248
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 0.0217 - val_loss: 0.0326
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 0.0220 - val_loss: 0.0233
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 459ms/step - loss: 0.0191 - val_loss: 0.0240
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 0.0183 - val_loss: 0.0259
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 478ms/step - loss: 0.0170 - val_loss: 0.0231
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 475ms/step - loss: 0.0165 - val_loss: 0.0195
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - loss: 0.0154 - val_loss: 0.0187
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - loss: 0.0127 - val_loss: 0.0178
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - loss: 0.0123 - val_loss: 0.0160
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - loss: 0.0137 - val_loss: 0.0164
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - loss: 0.0129 - val_loss: 0.0161
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - loss: 0.0123 - val_loss: 0.0167
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - loss: 0.0120 - val_loss: 0.0156
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 0.0124 - val_loss: 0.0151
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - loss: 0.0124 - val_loss: 0.0152
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 397ms/step - loss: 0.0109 - val_loss: 0.0145
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 406ms/step - loss: 0.0109 - val_loss: 0.0148
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - loss: 0.0117 - val_loss: 0.0146
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - loss: 0.0118 - val_loss: 0.0154
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 519ms/step - loss: 0.0122 - val_loss: 0.0138
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - loss: 0.0109 - val_loss: 0.0137
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - loss: 0.0103 - val_loss: 0.0145
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 456ms/step - loss: 0.0083 - val_loss: 0.0136
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 456ms/step - loss: 0.0105 - val_loss: 0.0128
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - loss: 0.0100 - val_loss: 0.0127
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 367ms/step - loss: 0.0108 - val_loss: 0.0141
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 366ms/step - loss: 0.0101 - val_loss: 0.0128
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 348ms/step - loss: 0.0092 - val_loss: 0.0129
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - loss: 0.0102 - val_loss: 0.0133
# Epoch 41/150
# ...
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.0075 - val_loss: 0.0117
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - loss: 0.0084 - val_loss: 0.0123
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - loss: 0.0075 - val_loss: 0.0110
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0078 - val_loss: 0.0126
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0073 - val_loss: 0.0113
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0065 - val_loss: 0.0117
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0066 - val_loss: 0.0115
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - loss: 0.0066 - val_loss: 0.0113
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - loss: 0.0065 - val_loss: 0.0115
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - loss: 0.0076 - val_loss: 0.0114
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0072 - val_loss: 0.0116
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - loss: 0.0063 - val_loss: 0.0112
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 314ms/step - loss: 0.0072 - val_loss: 0.0138
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.0069 - val_loss: 0.0112
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0062 - val_loss: 0.0119
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 314ms/step - loss: 0.0065 - val_loss: 0.0115
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - loss: 0.0059 - val_loss: 0.0113
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0062 - val_loss: 0.0114
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Epoch 1/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 397ms/step - loss: 0.1263 - val_loss: 0.0612
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - loss: 0.0541 - val_loss: 0.0599
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - loss: 0.0544 - val_loss: 0.0467
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - loss: 0.0431 - val_loss: 0.0398
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0365 - val_loss: 0.0358
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0275 - val_loss: 0.0325
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - loss: 0.0231 - val_loss: 0.0295
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0243 - val_loss: 0.0285
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - loss: 0.0223 - val_loss: 0.0282
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - loss: 0.0255 - val_loss: 0.0264
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0209 - val_loss: 0.0251
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - loss: 0.0232 - val_loss: 0.0236
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - loss: 0.0227 - val_loss: 0.0254
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - loss: 0.0236 - val_loss: 0.0264
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - loss: 0.0228 - val_loss: 0.0221
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - loss: 0.0184 - val_loss: 0.0199
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 316ms/step - loss: 0.0152 - val_loss: 0.0198
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 342ms/step - loss: 0.0160 - val_loss: 0.0194
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0167 - val_loss: 0.0183
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - loss: 0.0162 - val_loss: 0.0177
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0167 - val_loss: 0.0167
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0145 - val_loss: 0.0163
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - loss: 0.0150 - val_loss: 0.0175
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 316ms/step - loss: 0.0145 - val_loss: 0.0159
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - loss: 0.0157 - val_loss: 0.0195
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0169 - val_loss: 0.0173
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - loss: 0.0155 - val_loss: 0.0170
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0139 - val_loss: 0.0169
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - loss: 0.0151 - val_loss: 0.0201
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - loss: 0.0138 - val_loss: 0.0166
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - loss: 0.0135 - val_loss: 0.0151
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0137 - val_loss: 0.0148
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - loss: 0.0142 - val_loss: 0.0159
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0135 - val_loss: 0.0149
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0133 - val_loss: 0.0144
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - loss: 0.0123 - val_loss: 0.0165
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - loss: 0.0136 - val_loss: 0.0167
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - loss: 0.0155 - val_loss: 0.0153
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - loss: 0.0132 - val_loss: 0.0160
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - loss: 0.0123 - val_loss: 0.0162
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - loss: 0.0125 - val_loss: 0.0146
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - loss: 0.0126 - val_loss: 0.0153
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0118 - val_loss: 0.0152
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0131 - val_loss: 0.0142
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - loss: 0.0117 - val_loss: 0.0129
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0122 - val_loss: 0.0135
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 328ms/step - loss: 0.0122 - val_loss: 0.0144
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - loss: 0.0117 - val_loss: 0.0155
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 314ms/step - loss: 0.0130 - val_loss: 0.0144
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - loss: 0.0124 - val_loss: 0.0146
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - loss: 0.0109 - val_loss: 0.0138
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0117 - val_loss: 0.0127
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0116 - val_loss: 0.0135
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0109 - val_loss: 0.0131
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0123 - val_loss: 0.0145
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0115 - val_loss: 0.0143
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0127 - val_loss: 0.0133
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - loss: 0.0105 - val_loss: 0.0143
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 342ms/step - loss: 0.0107 - val_loss: 0.0127
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - loss: 0.0111 - val_loss: 0.0140
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - loss: 0.0104 - val_loss: 0.0123
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0111 - val_loss: 0.0130
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0112 - val_loss: 0.0138
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - loss: 0.0116 - val_loss: 0.0128
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - loss: 0.0105 - val_loss: 0.0120
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0108 - val_loss: 0.0122
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0113 - val_loss: 0.0127
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - loss: 0.0102 - val_loss: 0.0120
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0120 - val_loss: 0.0140
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - loss: 0.0107 - val_loss: 0.0119
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0102 - val_loss: 0.0124
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0110 - val_loss: 0.0151
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - loss: 0.0107 - val_loss: 0.0125
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 329ms/step - loss: 0.0092 - val_loss: 0.0116
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - loss: 0.0095 - val_loss: 0.0131
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0099 - val_loss: 0.0117
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 354ms/step - loss: 0.0101 - val_loss: 0.0114
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0102 - val_loss: 0.0116
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - loss: 0.0094 - val_loss: 0.0127
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0107 - val_loss: 0.0126
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0102 - val_loss: 0.0117
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - loss: 0.0097 - val_loss: 0.0114
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 329ms/step - loss: 0.0093 - val_loss: 0.0130
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0088 - val_loss: 0.0126
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - loss: 0.0098 - val_loss: 0.0125
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - loss: 0.0096 - val_loss: 0.0110
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0104 - val_loss: 0.0110
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - loss: 0.0099 - val_loss: 0.0124
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - loss: 0.0099 - val_loss: 0.0123
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 341ms/step - loss: 0.0100 - val_loss: 0.0120
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - loss: 0.0088 - val_loss: 0.0105
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - loss: 0.0092 - val_loss: 0.0115
# Epoch 97/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 342ms/step - loss: 0.0101 - val_loss: 0.0113
# Epoch 98/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0093 - val_loss: 0.0115
# Epoch 99/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - loss: 0.0092 - val_loss: 0.0113
# Epoch 100/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0092 - val_loss: 0.0118
# Epoch 101/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - loss: 0.0087 - val_loss: 0.0110
# Epoch 102/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - loss: 0.0088 - val_loss: 0.0114
# Epoch 103/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - loss: 0.0086 - val_loss: 0.0113
# Epoch 104/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.0089 - val_loss: 0.0121
# Epoch 105/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.0095 - val_loss: 0.0117
# Epoch 106/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0088 - val_loss: 0.0133
# Epoch 107/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - loss: 0.0089 - val_loss: 0.0109
# Epoch 108/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - loss: 0.0091 - val_loss: 0.0114
# Epoch 109/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - loss: 0.0086 - val_loss: 0.0121
# Epoch 110/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0090 - val_loss: 0.0122
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Forecasting and evaluation completed.
